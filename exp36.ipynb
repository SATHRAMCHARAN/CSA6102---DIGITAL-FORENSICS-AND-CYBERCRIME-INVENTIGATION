# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6102---DIGITAL-FORENSICS-AND-CYBERCRIME-INVENTIGATION/blob/main/exp36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def recover_deleted_messages(sms_table):
    """
    sms_table: list of dictionaries with:
        - is_deleted (bool)
        - overwritten (bool)

    Returns a list of deleted but recoverable messages.
    """
    recoverable = [
        row for row in sms_table
        if row["is_deleted"] and not row["overwritten"]
    ]
    return recoverable


def summarize_table(sms_table):
    """
    Returns a summary of the SMS table.
    """
    active = [r for r in sms_table if not r["is_deleted"]]
    recoverable = recover_deleted_messages(sms_table)
    lost = [
        r for r in sms_table
        if r["is_deleted"] and r["overwritten"]
    ]

    return {
        "active": len(active),
        "recoverable": len(recoverable),
        "permanently_lost": len(lost)
    }


# Example usage
sms_table = [
    {"id": 1, "message": "Hello", "is_deleted": False, "overwritten": False},
    {"id": 2, "message": "Meeting at 5", "is_deleted": True, "overwritten": False},
    {"id": 3, "message": "OTP: 123456", "is_deleted": True, "overwritten": True},
    {"id": 4, "message": "How are you?", "is_deleted": False, "overwritten": False},
]

recoverable = recover_deleted_messages(sms_table)
summary = summarize_table(sms_table)

print("Recoverable Messages:")
print(recoverable)

print("\nSummary:")
print(summary)
# Out:
# Recoverable Messages:
# [{'id': 2, 'message': 'Meeting at 5', 'is_deleted': True, 'overwritten': False}]
#
# Summary:
# {'active': 2, 'recoverable': 1, 'permanently_lost': 1}
