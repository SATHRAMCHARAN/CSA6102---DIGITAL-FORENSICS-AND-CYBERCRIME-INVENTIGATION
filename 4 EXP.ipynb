# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6102---DIGITAL-FORENSICS-AND-CYBERCRIME-INVENTIGATION/blob/main/4%20EXP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

domain = input("Enter domain name: ")

try:
    ip_address = socket.gethostbyname(domain)

    print("\nDNS Lookup Result")
    print("-" * 30)
    print("Domain :", domain)
    print("IP Address :", ip_address)

    hostname, aliases, addresses = socket.gethostbyname_ex(domain)

    print("Hostname :", hostname)
    print("Aliases :", aliases)
    print("Addresses :", addresses)

except socket.gaierror:
    print("DNS lookup failed. Invalid domain or no DNS record found.")
# Out:
# Enter domain name: google.com
#
# DNS Lookup Result
# ------------------------------
# Domain : google.com
# IP Address : 142.251.107.100
# Hostname : google.com
# Aliases : []
# Addresses : ['142.251.107.100', '142.251.107.113', '142.251.107.138', '142.251.107.101', '142.251.107.102', '142.251.107.139']
